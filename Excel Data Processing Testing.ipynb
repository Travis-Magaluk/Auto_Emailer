# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Employee Wellness Spreadsheet 2.xlsx')

# %%
# df = df.drop(df.loc[0:17].index, axis=0, inplace=True)
# print(df.type())

# %%
df.head(30)
# Out:
#   Group Number       Group Name     Member ID Last Name First Name   MI  \
# 0     G1007098  WASATCH ACADEMY  801755286-00   Magaluk     Travis    W
# 1     G1007098  WASATCH ACADEMY  800969400-00     Prows   Michelle
# 2     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
# 3     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
# 4     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
# 5     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
# 6     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
# 7     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
# 8          NaN              NaN           NaN       NaN        NaN  NaN
# 9     G1007098  WASATCH ACADEMY           NaN       NaN        NaN
#
#    Birth Date            Plan    Product Member Status  ... Apr.2 May.2 Jun.2  \
# 0  05/29/1987         MEDICAL      SHARE    SUBSCRIBER  ...
# ...

# %%
df.columns
# Out:
# Index(['Group Number', 'Group Name', 'Member ID', 'Last Name', 'First Name',
#        'MI', 'Birth Date', 'Plan', 'Product', 'Member Status', 'Plan Type',
#        'Plan Status', 'Plan Start Date', 'Plan End Date',
#        'SelectHealth Account', 'VP Account',
#        'Last Health Assessment (VP Health Check)',
#        'Last Digital Coaching (1 VP Journey)',
#        'Health Screening (Worksite or Provider)', 'Health Screening Due Date',
#        'Select Primary Care Provider',
#        'Activity Campaigns (VP Team Challenges) **', 'Jan', 'Feb', 'Mar',
#        'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec',
#        'VP Team Challenges Subtotal', 'Jan.1', 'Feb.1', 'Mar.1', 'Apr.1',
#        'May.1', 'Jun.1', 'Jul.1', 'Aug.1', 'Sep.1', 'Oct.1', 'Nov.1', 'Dec.1',
#        '7,000 Steps Subtotal', 'Jan.2', 'Feb.2', 'Mar.2', 'Apr.2', 'May.2',
#        'Jun.2', 'Jul.2', 'Aug.2', 'Sep.2', 'Oct.2', 'Nov.2', 'Dec.2',
#        'Healthy Habits Subtotal'],
# ...

# %%
list_of_column_names = ['Last Name', 'First Name', 'Member Status', 'Plan Status', 'Last Health Assessment (VP Health Check)', 'Last Digital Coaching (1 VP Journey)', 'Health Screening (Worksite or Provider)', 'Activity Campaigns (VP Team Challenges) **']

df_sort = df[list_of_column_names]

# %%
df_sort.head()

df_sort = df_sort[df_sort['Member Status'] == 'SUBSCRIBER']

df_sort.head()
# Out:
#   Last Name First Name Member Status Plan Status  \
# 0   Magaluk     Travis    SUBSCRIBER      ACTIVE
# 1     Prows   Michelle    SUBSCRIBER      ACTIVE
# 5       NaN        NaN    SUBSCRIBER      ACTIVE
# 6       NaN        NaN    SUBSCRIBER      ACTIVE
# 7       NaN        NaN    SUBSCRIBER      ACTIVE
#
#   Last Health Assessment (VP Health Check)  \
# 0                               11/21/2021
# 1                               08/14/2021
# 5
# 6                               11/06/2021
# 7                               01/31/2022
#
#   Last Digital Coaching (1 VP Journey)  \
# 0                           12/15/2021
# 1                           08/13/2021
# 5
# 6                           02/13/2022
# 7                           03/18/2022
#
#   Health Screening (Worksite or Provider)  \
# 0                                       X
# 1                                       X
# 5                                       X
# 6                                       X
# ...
