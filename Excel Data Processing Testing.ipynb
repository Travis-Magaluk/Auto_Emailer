# %% [markdown]
# # Good cleaning algorithm here to get the spreadsheet in and cleaned up.

# %%
import numpy as np
import pandas as pd
import gspread

# %%
df1 = pd.read_excel('Employee Wellness Spreadsheet 2.xlsx')

# %%
# df = df.drop(df.loc[0:17].index, axis=0, inplace=True)
# print(df.type())

# %%
df1.head(5)
# Out:
#   Group Number       Group Name     Member ID Last Name First Name   MI  \
# 0     G1007098  WASATCH ACADEMY  801755286-00   Magaluk     Travis    W
# 1     G1007098  WASATCH ACADEMY           NaN     Prows   Michelle
# 2     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
# 3     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
# 4     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
#
#    Birth Date     Plan Product Member Status  ... Apr.2 May.2 Jun.2 Jul.2  \
# 0  05/29/1987  MEDICAL   SHARE    SUBSCRIBER  ...
# 1  08/13/1970  MEDICAL   SHARE    SUBSCRIBER  ...
# 2         NaN  MEDICAL   SHARE        SPOUSE  ...
# 3         NaN  MEDICAL   SHARE     DEPENDENT  ...
# 4         NaN  MEDICAL   SHARE     DEPENDENT  ...
#
#   Aug.2 Sep.2 Oct.2 Nov.2 Dec.2 Healthy Habits Subtotal
# 0                                                   0.0
# 1     X     X           X                           5.0
# 2                                                   0.0
# 3                                                   0.0
# 4                                                   0.0
#
# [5 rows x 61 columns]

# %%
# df1.columns

# %%
# Only Columns we need here sorting out the unnecessary column names. 

list_of_column_names = ['Last Name', 'First Name', 'Member Status', 'Plan Status', 'Last Health Assessment \
(VP Health Check)', 'Last Digital Coaching (1 VP Journey)', 'Health Screening (Worksite or Provider)','Activity \
Campaigns (VP Team Challenges) **']

df_sort = df1[list_of_column_names]

# %%
df_sort.head()

# Filter out only subscribers.
df_sort = df_sort[df_sort['Member Status'] == 'SUBSCRIBER']

df_sort.head(10)
# Out:
#      Last Name First Name Member Status Plan Status  \
# 0      Magaluk     Travis    SUBSCRIBER      ACTIVE
# 1        Prows   Michelle    SUBSCRIBER      ACTIVE
# 5     Anderson       Ryan    SUBSCRIBER      ACTIVE
# 6     Peterson       Luke    SUBSCRIBER      ACTIVE
# 7   Schlachter   Margaret    SUBSCRIBER      ACTIVE
# 8         Dole        Bob    SUBSCRIBER         NaN
# 9       Madsen     Travis    SUBSCRIBER      ACTIVE
# 10    Townsend       Pete    SUBSCRIBER         NaN
# 11     McQuivy      Cassy    SUBSCRIBER         NaN
#
#    Last Health Assessment (VP Health Check)  \
# 0                                11/21/2021
# 1                                08/14/2021
# 5
# 6                                11/06/2021
# 7                                01/31/2022
# 8                                       NaN
# 9
# 10                                      NaN
# 11                                      NaN
#
#    Last Digital Coaching (1 VP Journey)  \
# 0                            12/15/2021
# 1                            08/13/2021
# 5
# 6                            02/13/2022
# 7                            03/18/2022
# 8                                   NaN
# 9
# 10                                  NaN
# 11                                  NaN
#
#    Health Screening (Worksite or Provider)  \
# 0                                        X
# 1                                        X
# 5                                        X
# 6                                        X
# 7                                        X
# 8                                      NaN
# 9
# 10                                     NaN
# 11                                     NaN
#
#     Activity Campaigns (VP Team Challenges) **
# 0                                          2.0
# 1                                          6.0
# 5                                          1.0
# 6                                          2.0
# 7                                          9.0
# 8                                          NaN
# 9                                          0.0
# 10                                         NaN
# 11                                         NaN

# %%
# Replacing any blank cells with NaN
df_sort = df_sort.replace(r'^\s*$', np.nan, regex=True)

# %%
df_sort.head(20)
# Out:
#      Last Name First Name Member Status Plan Status  \
# 0      Magaluk     Travis    SUBSCRIBER      ACTIVE
# 1        Prows   Michelle    SUBSCRIBER      ACTIVE
# 5     Anderson       Ryan    SUBSCRIBER      ACTIVE
# 6     Peterson       Luke    SUBSCRIBER      ACTIVE
# 7   Schlachter   Margaret    SUBSCRIBER      ACTIVE
# 8         Dole        Bob    SUBSCRIBER         NaN
# 9       Madsen     Travis    SUBSCRIBER      ACTIVE
# 10    Townsend       Pete    SUBSCRIBER         NaN
# 11     McQuivy      Cassy    SUBSCRIBER         NaN
#
#    Last Health Assessment (VP Health Check)  \
# 0                                11/21/2021
# 1                                08/14/2021
# 5                                       NaN
# 6                                11/06/2021
# 7                                01/31/2022
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
#
#    Last Digital Coaching (1 VP Journey)  \
# 0                            12/15/2021
# 1                            08/13/2021
# 5                                   NaN
# 6                            02/13/2022
# 7                            03/18/2022
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
#
#    Health Screening (Worksite or Provider)  \
# 0                                        X
# 1                                        X
# 5                                        X
# 6                                        X
# 7                                        X
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
#
#     Activity Campaigns (VP Team Challenges) **
# 0                                          2.0
# 1                                          6.0
# 5                                          1.0
# 6                                          2.0
# 7                                          9.0
# 8                                          NaN
# 9                                          0.0
# 10                                         NaN
# 11                                         NaN

# %%
# Pulling columns where we want to see if people have done something or not.  These columns are being prepared 
# for converting to 0's or 1's as a yes or no response. 

df_parse = df_sort[['Last Health Assessment (VP Health Check)', 'Last Digital Coaching (1 VP Journey)', 'Health Screening (Worksite or Provider)']]
df_parse.head(20)
# Out:
#    Last Health Assessment (VP Health Check)  \
# 0                                11/21/2021
# 1                                08/14/2021
# 5                                       NaN
# 6                                11/06/2021
# 7                                01/31/2022
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
#
#    Last Digital Coaching (1 VP Journey)  \
# 0                            12/15/2021
# 1                            08/13/2021
# 5                                   NaN
# 6                            02/13/2022
# 7                            03/18/2022
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
#
#    Health Screening (Worksite or Provider)
# 0                                        X
# 1                                        X
# 5                                        X
# 6                                        X
# 7                                        X
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN

# %%
# Dropping columns above from df_sort. Will remerge later. 

cols = ['Last Health Assessment (VP Health Check)', 'Last Digital Coaching (1 VP Journey)', 'Health Screening (Worksite or Provider)']
df_sort = df_sort.drop(labels=cols,axis=1)

# %%
df_sort.head(20)
# Out:
#      Last Name First Name Member Status Plan Status  \
# 0      Magaluk     Travis    SUBSCRIBER      ACTIVE
# 1        Prows   Michelle    SUBSCRIBER      ACTIVE
# 5     Anderson       Ryan    SUBSCRIBER      ACTIVE
# 6     Peterson       Luke    SUBSCRIBER      ACTIVE
# 7   Schlachter   Margaret    SUBSCRIBER      ACTIVE
# 8         Dole        Bob    SUBSCRIBER         NaN
# 9       Madsen     Travis    SUBSCRIBER      ACTIVE
# 10    Townsend       Pete    SUBSCRIBER         NaN
# 11     McQuivy      Cassy    SUBSCRIBER         NaN
#
#     Activity Campaigns (VP Team Challenges) **
# 0                                          2.0
# 1                                          6.0
# 5                                          1.0
# 6                                          2.0
# 7                                          9.0
# 8                                          NaN
# 9                                          0.0
# 10                                         NaN
# 11                                         NaN

# %%
df_sort.dtypes
# Out:
# Last Name                                      object
# First Name                                     object
# Member Status                                  object
# Plan Status                                    object
# Activity Campaigns (VP Team Challenges) **    float64
# dtype: object

# %%
df_parse.head()
# Out:
#   Last Health Assessment (VP Health Check)  \
# 0                               11/21/2021
# 1                               08/14/2021
# 5                                      NaN
# 6                               11/06/2021
# 7                               01/31/2022
#
#   Last Digital Coaching (1 VP Journey) Health Screening (Worksite or Provider)
# 0                           12/15/2021                                       X
# 1                           08/13/2021                                       X
# 5                                  NaN                                       X
# 6                           02/13/2022                                       X
# 7                           03/18/2022                                       X

# %%
# This is converting anything that is null to a zero "int" dtype and anything notnull to a one "int" dtype.
 
df_parse = df_parse.notnull().astype('int')

# %%
df_parse.head()
# Out:
#    Last Health Assessment (VP Health Check)  \
# 0                                         1
# 1                                         1
# 5                                         0
# 6                                         1
# 7                                         1
#
#    Last Digital Coaching (1 VP Journey)  \
# 0                                     1
# 1                                     1
# 5                                     0
# 6                                     1
# 7                                     1
#
#    Health Screening (Worksite or Provider)
# 0                                        1
# 1                                        1
# 5                                        1
# 6                                        1
# 7                                        1

# %%
# Testing iloc function and getting a feel for how it will come out. 
# Feel that it will be easier for program to run line by line through the data rather than create lists for each
# column. 

s1 = df_sort.iloc[1]

# %%
print(s1)
# Out:
# Last Name                                          Prows
# First Name                                      Michelle
# Member Status                                 SUBSCRIBER
# Plan Status                                       ACTIVE
# Activity Campaigns (VP Team Challenges) **           6.0
# Name: 1, dtype: object

# %%
type(s1[4])
# Out:
# numpy.float64

# %%
# Merging these two dfs back together to one cleaned up file from the health insurance company. 

result = pd.concat([df_sort, df_parse], axis=1)

# %%
result.head()
# Out:
#     Last Name First Name Member Status Plan Status  \
# 0     Magaluk     Travis    SUBSCRIBER      ACTIVE
# 1       Prows   Michelle    SUBSCRIBER      ACTIVE
# 5    Anderson       Ryan    SUBSCRIBER      ACTIVE
# 6    Peterson       Luke    SUBSCRIBER      ACTIVE
# 7  Schlachter   Margaret    SUBSCRIBER      ACTIVE
#
#    Activity Campaigns (VP Team Challenges) **  \
# 0                                         2.0
# 1                                         6.0
# 5                                         1.0
# 6                                         2.0
# 7                                         9.0
#
#    Last Health Assessment (VP Health Check)  \
# 0                                         1
# 1                                         1
# 5                                         0
# 6                                         1
# 7                                         1
#
#    Last Digital Coaching (1 VP Journey)  \
# 0                                     1
# 1                                     1
# 5                                     0
# 6                                     1
# 7                                     1
#
#    Health Screening (Worksite or Provider)
# 0                                        1
# 1                                        1
# 5                                        1
# 6                                        1
# 7                                        1

# %%
# Pulling in data from our gsheets database into a new dataframe. 

gc = gspread.service_account(filename="/Users/travismagaluk/Documents/Coding Work/Other Wasatch Projects/Health_and_Wellness_Emails/excellent-range-359215-54acfee9562d.json")

sh = gc.open("Health And Wellness Tracking")

ws = sh.worksheet('Sheet1')

df = pd.DataFrame(ws.get_all_records())

df.head()
# Out:
#   First Name   Last Name                           Email Address  \
# 0     Travis     Magaluk       travis.magaluk@wasatchacademy.org
# 1       John       Pikus
# 2       Ryan    Anderson        ryan.anderson@wasatchacademy.org
# 3       Luke    Peterson        luke.peterson@wasatchacademy.org
# 4   Margaret  Schlachter  margaret.schlachter@wasatchacademy.org
#
#    Initiatives Completed  Reimbursements Received  Reimbursement Left  \
# 0                      0                        0                 100
# 1                      0                        0                 100
# 2                      4                        0                 100
# 3                      2                        0                 100
# 4                      5                       50                  50
#
#   Last Email Sent (Y/N) Current Employee (Y/N)
# 0                     N                      Y
# 1                     N                      N
# 2                     N                      Y
# 3                     N                      Y
# 4                     N                      Y

# %%
# Play around with getting these to merge into one nice dataframe that we can use with the email generation part
# of this program. 

test = pd.merge(result, df, how="inner", on=["First Name", "Last Name"])

# %%
test.head()
# Out:
#     Last Name First Name Member Status Plan Status  \
# 0     Magaluk     Travis    SUBSCRIBER      ACTIVE
# 1    Anderson       Ryan    SUBSCRIBER      ACTIVE
# 2    Peterson       Luke    SUBSCRIBER      ACTIVE
# 3  Schlachter   Margaret    SUBSCRIBER      ACTIVE
#
#    Activity Campaigns (VP Team Challenges) **  \
# 0                                         2.0
# 1                                         1.0
# 2                                         2.0
# 3                                         9.0
#
#    Last Health Assessment (VP Health Check)  \
# 0                                         1
# 1                                         0
# 2                                         1
# 3                                         1
#
#    Last Digital Coaching (1 VP Journey)  \
# 0                                     1
# 1                                     0
# 2                                     1
# 3                                     1
#
#    Health Screening (Worksite or Provider)  \
# 0                                        1
# 1                                        1
# 2                                        1
# 3                                        1
#
#                             Email Address  Initiatives Completed  \
# 0       travis.magaluk@wasatchacademy.org                      0
# 1        ryan.anderson@wasatchacademy.org                      4
# 2        luke.peterson@wasatchacademy.org                      2
# 3  margaret.schlachter@wasatchacademy.org                      5
#
#    Reimbursements Received  Reimbursement Left Last Email Sent (Y/N)  \
# 0                        0                 100                     N
# 1                        0                 100                     N
# 2                        0                 100                     N
# 3                       50                  50                     N
#
#   Current Employee (Y/N)
# 0                      Y
# 1                      Y
# 2                      Y
# 3                      Y

# %%
test.shape
# Out:
# (4, 14)
