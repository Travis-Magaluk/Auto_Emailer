# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Employee Wellness Spreadsheet.xlsx')

# %%
# df = df.drop(df.loc[0:17].index, axis=0, inplace=True)
# print(df.type())

# %%
df.head()
# Out:
#   Note: Due to various circumstances, there could be enrollment changes/corrections mid plan year in our system that causes SelectHealth enrollment to end the current plan record and create a new plan record with no break in coverage. These dates may not reflect the initial Plan Start Date, rather, the report shows dates for the most recent plan record after changes/corrections are made.  \
# 0                                                NaN
# 1                                                NaN
# 2
# 3                                NA = Not Applicable
# 4                                  NE = Not Eligible
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 51 Unnamed: 52 Unnamed: 53  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 2        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 3        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4        NaN        NaN        NaN  ...         NaN         NaN         NaN
#
#   Unnamed: 54 Unnamed: 55 Unnamed: 56 Unnamed: 57 Unnamed: 58 Unnamed: 59  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 60
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 61 columns]

# %%
df = df.rename(columns=df.iloc[16])

# %%
df.head()
# Out:
#           Group Number Group Name Member ID Last Name First Name   MI  \
# 0                  NaN        NaN       NaN       NaN        NaN  NaN
# 1                  NaN        NaN       NaN       NaN        NaN  NaN
# 2                             NaN       NaN       NaN        NaN  NaN
# 3  NA = Not Applicable        NaN       NaN       NaN        NaN  NaN
# 4    NE = Not Eligible        NaN       NaN       NaN        NaN  NaN
#
#   Birth Date Plan Product Member Status  ...  Apr  May  Jun  Jul  Aug  Sep  \
# 0        NaN  NaN     NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1        NaN  NaN     NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 2        NaN  NaN     NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 3        NaN  NaN     NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 4        NaN  NaN     NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
#
#    Oct  Nov  Dec Healthy Habits Subtotal
# 0  NaN  NaN  NaN                     NaN
# 1  NaN  NaN  NaN                     NaN
# 2  NaN  NaN  NaN                     NaN
# 3  NaN  NaN  NaN                     NaN
# 4  NaN  NaN  NaN                     NaN
#
# [5 rows x 61 columns]

# %%
df = df.drop(df.index[0:17])

# %%
df.head()
# Out:
#    Group Number       Group Name     Member ID Last Name First Name   MI  \
# 17     G1007098  WASATCH ACADEMY  801755286-00   Magaluk     Travis    W
# 18     G1007098  WASATCH ACADEMY  800969400-00     Prows   Michelle
# 19     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
# 20     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
# 21     G1007098  WASATCH ACADEMY           NaN       NaN        NaN  NaN
#
#     Birth Date     Plan Product Member Status  ... Apr May Jun Jul Aug Sep  \
# 17  05/29/1987  MEDICAL   SHARE    SUBSCRIBER  ...
# 18  08/13/1970  MEDICAL   SHARE    SUBSCRIBER  ...                   X   X
# 19         NaN  MEDICAL   SHARE        SPOUSE  ...
# 20         NaN  MEDICAL   SHARE     DEPENDENT  ...
# 21         NaN  MEDICAL   SHARE     DEPENDENT  ...
#
#    Oct Nov Dec Healthy Habits Subtotal
# 17                                   0
# 18       X                           5
# 19                                   0
# 20                                   0
# 21                                   0
#
# [5 rows x 61 columns]

# %%
df.columns
# Out:
# Index(['Group Number', 'Group Name', 'Member ID', 'Last Name', 'First Name',
#        'MI', 'Birth Date', 'Plan', 'Product', 'Member Status', 'Plan Type',
#        'Plan Status', 'Plan Start Date', 'Plan End Date',
#        'SelectHealth Account', 'VP Account',
#        'Last Health Assessment (VP Health Check)',
#        'Last Digital Coaching (1 VP Journey)',
#        'Health Screening (Worksite or Provider)', 'Health Screening Due Date',
#        'Select Primary Care Provider',
#        'Activity Campaigns (VP Team Challenges) **', 'Jan', 'Feb', 'Mar',
#        'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec',
#        'VP Team Challenges Subtotal', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
#        'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', '7,000 Steps Subtotal', 'Jan',
#        'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov',
#        'Dec', 'Healthy Habits Subtotal'],
#       dtype='object')

# %%
list_of_column_names = ['Last Name', 'First Name', 'Member Status', 'Plan Status', 'Last Health Assessment (VP Health Check)', 'Last Digital Coaching (1 VP Journey)', 'Health Screening (Worksite or Provider)', 'Activity Campaigns (VP Team Challenges) **']

df_sort = df[list_of_column_names]

# %%
df_sort.head()

df_sort = df_sort[df_sort['Member Status'] == 'SUBSCRIBER']

df_sort.head()
# Out:
#    Last Name First Name Member Status Plan Status  \
# 17   Magaluk     Travis    SUBSCRIBER      ACTIVE
# 18     Prows   Michelle    SUBSCRIBER      ACTIVE
# 22       NaN        NaN    SUBSCRIBER      ACTIVE
# 23       NaN        NaN    SUBSCRIBER      ACTIVE
# 24       NaN        NaN    SUBSCRIBER      ACTIVE
#
#    Last Health Assessment (VP Health Check)  \
# 17                               11/21/2021
# 18                               08/14/2021
# 22
# 23                               11/06/2021
# 24                               01/31/2022
#
#    Last Digital Coaching (1 VP Journey)  \
# 17                           12/15/2021
# 18                           08/13/2021
# 22
# 23                           02/13/2022
# 24                           03/18/2022
#
#    Health Screening (Worksite or Provider)  \
# 17                                       X
# 18                                       X
# 22                                       X
# 23                                       X
# 24                                       X
#
#    Activity Campaigns (VP Team Challenges) **
# 17                                          2
# 18                                          6
# 22                                          1
# 23                                          2
# 24                                          9
