# %% [markdown]
# # Good cleaning algorithm here to get the spreadsheet in and cleaned up.

# %%
import numpy as np
import pandas as pd
import gspread

# %%
df1 = pd.read_excel('../E_HW_data_12_7.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df1 = pd.read_excel('../E_HW_data_12_7.xlsx')
#
# File ~/opt/miniconda3/envs/emailer/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/emailer/lib/python3.10/site-packages/pandas/io/excel/_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File ~/opt/miniconda3/envs/emailer/lib/python3.10/site-packages/pandas/io/excel/_base.py:1376, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1374     ext = "xls"
#    1375 else:
# -> 1376     ext = inspect_excel_format(
#    1377         content_or_path=path_or_buffer, storage_options=storage_options
#    1378     )
#    1379     if ext is None:
#    1380         raise ValueError(
#    1381             "Excel file format cannot be determined, you must specify "
#    1382             "an engine manually."
#    1383         )
#
# File ~/opt/miniconda3/envs/emailer/lib/python3.10/site-packages/pandas/io/excel/_base.py:1250, in inspect_excel_format(content_or_path, storage_options)
#    1247 if isinstance(content_or_path, bytes):
#    1248     content_or_path = BytesIO(content_or_path)
# -> 1250 with get_handle(
#    1251     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252 ) as handle:
#    1253     stream = handle.handle
#    1254     stream.seek(0)
#
# File ~/opt/miniconda3/envs/emailer/lib/python3.10/site-packages/pandas/io/common.py:795, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#    (...)
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
# --> 795         handle = open(handle, ioargs.mode)
#     796     handles.append(handle)
#     798 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../E_HW_data_12_7.xlsx'

# %%
# df = df.drop(df.loc[0:17].index, axis=0, inplace=True)
# print(df.type())

# %%
df1.head(5)

df1.columns
# Out:
# Index(['Group Number', 'Group Name', 'Member ID', 'Last Name', 'First Name',
#        'MI', 'Birth Date', 'Plan', 'Product', 'Member Status', 'Plan Type',
#        'Plan Status', 'Plan Start Date', 'Plan End Date',
#        'SelectHealth Account', 'VP Account',
#        'Last Health Assessment (VP Health Check)',
#        'Last Digital Coaching (1 VP Journey)',
#        'Health Screening (Worksite or Provider)', 'Health Screening Due Date',
#        'Select Primary Care Provider',
#        'Activity Campaigns (VP Team Challenges) **', 'Jan', 'Feb', 'Mar',
#        'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec',
#        'VP Team Challenges Subtotal', 'Jan.1', 'Feb.1', 'Mar.1', 'Apr.1',
#        'May.1', 'Jun.1', 'Jul.1', 'Aug.1', 'Sep.1', 'Oct.1', 'Nov.1', 'Dec.1',
#        '7,000 Steps Subtotal', 'Jan.2', 'Feb.2', 'Mar.2', 'Apr.2', 'May.2',
#        'Jun.2', 'Jul.2', 'Aug.2', 'Sep.2', 'Oct.2', 'Nov.2', 'Dec.2',
#        'Healthy Habits Subtotal'],
#       dtype='object')

# %%
# df1.columns

# %%
# Only Columns we need here sorting out the unnecessary column names. 

list_of_column_names = ['Last Name', 'First Name', 'Member Status', 'Plan Status', 'Product', 'Plan Type', 'Last Health Assessment \
(VP Health Check)', 'Last Digital Coaching (1 VP Journey)', 'Health Screening (Worksite or Provider)','Activity \
Campaigns (VP Team Challenges) **']

df_sort = df1[list_of_column_names]

# %%
df_sort.head()

# Filter out only subscribers.
df_sort = df_sort[(df_sort['Member Status'] == 'SUBSCRIBER') & (df_sort['Product'] == 'SHARE') & (df_sort['Plan Type'] =='HDHP')]

df_sort.head(10)
# Out:
#     Last Name First Name Member Status Plan Status Product Plan Type  \
# 0     Magaluk     Travis    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 1       Prows   Michelle    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 5    Anderson       Ryan    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 6    Peterson       Luke    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 7  Schlachter   Margaret    SUBSCRIBER      ACTIVE   SHARE      HDHP
#
#   Last Health Assessment (VP Health Check)  \
# 0                               11/21/2021
# 1                               08/14/2021
# 5
# 6                                      NaN
# 7                               01/31/2022
#
#   Last Digital Coaching (1 VP Journey)  \
# 0                           12/15/2021
# 1                           08/13/2021
# 5
# 6                                  NaN
# 7                           03/18/2022
#
#   Health Screening (Worksite or Provider)  \
# 0                                       X
# 1                                       X
# 5                                       X
# 6                                     NaN
# 7                                       X
#
#    Activity Campaigns (VP Team Challenges) **
# 0                                         2.0
# 1                                         6.0
# 5                                         2.0
# 6                                         1.0
# 7                                         1.0

# %%
# Replacing any blank cells with NaN
df_sort = df_sort.replace(r'^\s*$', np.nan, regex=True)

# %%
df_sort.head(20)
# Out:
#     Last Name First Name Member Status Plan Status Product Plan Type  \
# 0     Magaluk     Travis    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 1       Prows   Michelle    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 5    Anderson       Ryan    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 6    Peterson       Luke    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 7  Schlachter   Margaret    SUBSCRIBER      ACTIVE   SHARE      HDHP
#
#   Last Health Assessment (VP Health Check)  \
# 0                               11/21/2021
# 1                               08/14/2021
# 5                                      NaN
# 6                                      NaN
# 7                               01/31/2022
#
#   Last Digital Coaching (1 VP Journey)  \
# 0                           12/15/2021
# 1                           08/13/2021
# 5                                  NaN
# 6                                  NaN
# 7                           03/18/2022
#
#   Health Screening (Worksite or Provider)  \
# 0                                       X
# 1                                       X
# 5                                       X
# 6                                     NaN
# 7                                       X
#
#    Activity Campaigns (VP Team Challenges) **
# 0                                         2.0
# 1                                         6.0
# 5                                         2.0
# 6                                         1.0
# 7                                         1.0

# %%
# Pulling columns where we want to see if people have done something or not.  These columns are being prepared 
# for converting to 0's or 1's as a yes or no response. 

df_parse = df_sort[['Last Health Assessment (VP Health Check)', 'Last Digital Coaching (1 VP Journey)', 'Health Screening (Worksite or Provider)']]
df_parse.head(20)
# Out:
#   Last Health Assessment (VP Health Check)  \
# 0                               11/21/2021
# 1                               08/14/2021
# 5                                      NaN
# 6                                      NaN
# 7                               01/31/2022
#
#   Last Digital Coaching (1 VP Journey) Health Screening (Worksite or Provider)
# 0                           12/15/2021                                       X
# 1                           08/13/2021                                       X
# 5                                  NaN                                       X
# 6                                  NaN                                     NaN
# 7                           03/18/2022                                       X

# %%
# Dropping columns above from df_sort. Will remerge later. 

cols = ['Last Health Assessment (VP Health Check)', 'Last Digital Coaching (1 VP Journey)', 'Health Screening (Worksite or Provider)']
df_sort = df_sort.drop(labels=cols,axis=1)

# %%
df_sort.head(20)
# Out:
#     Last Name First Name Member Status Plan Status Product Plan Type  \
# 0     Magaluk     Travis    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 1       Prows   Michelle    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 5    Anderson       Ryan    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 6    Peterson       Luke    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 7  Schlachter   Margaret    SUBSCRIBER      ACTIVE   SHARE      HDHP
#
#    Activity Campaigns (VP Team Challenges) **
# 0                                         2.0
# 1                                         6.0
# 5                                         2.0
# 6                                         1.0
# 7                                         1.0

# %%
df_sort.dtypes
# Out:
# Last Name                                      object
# First Name                                     object
# Member Status                                  object
# Plan Status                                    object
# Product                                        object
# Plan Type                                      object
# Activity Campaigns (VP Team Challenges) **    float64
# dtype: object

# %%
df_parse.head()
# Out:
#   Last Health Assessment (VP Health Check)  \
# 0                               11/21/2021
# 1                               08/14/2021
# 5                                      NaN
# 6                                      NaN
# 7                               01/31/2022
#
#   Last Digital Coaching (1 VP Journey) Health Screening (Worksite or Provider)
# 0                           12/15/2021                                       X
# 1                           08/13/2021                                       X
# 5                                  NaN                                       X
# 6                                  NaN                                     NaN
# 7                           03/18/2022                                       X

# %%
# This is converting anything that is null to a zero "int" dtype and anything notnull to a one "int" dtype.
 
df_parse = df_parse.notnull().astype('int')

# %%
df_parse.head()
# Out:
#    Last Health Assessment (VP Health Check)  \
# 0                                         1
# 1                                         1
# 5                                         0
# 6                                         0
# 7                                         1
#
#    Last Digital Coaching (1 VP Journey)  \
# 0                                     1
# 1                                     1
# 5                                     0
# 6                                     0
# 7                                     1
#
#    Health Screening (Worksite or Provider)
# 0                                        1
# 1                                        1
# 5                                        1
# 6                                        0
# 7                                        1

# %%
# Testing iloc function and getting a feel for how it will come out. 
# Feel that it will be easier for program to run line by line through the data rather than create lists for each
# column. 

s1 = df_sort.iloc[1]

# %%
print(s1)
# Out:
# Last Name                                          Prows
# First Name                                      Michelle
# Member Status                                 SUBSCRIBER
# Plan Status                                       ACTIVE
# Product                                            SHARE
# Plan Type                                           HDHP
# Activity Campaigns (VP Team Challenges) **           6.0
# Name: 1, dtype: object

# %%
type(s1[4])
# Out:
# str

# %%
# Merging these two dfs back together to one cleaned up file from the health insurance company. 

result = pd.concat([df_sort, df_parse], axis=1)

# %%
result.head()
# Out:
#     Last Name First Name Member Status Plan Status Product Plan Type  \
# 0     Magaluk     Travis    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 1       Prows   Michelle    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 5    Anderson       Ryan    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 6    Peterson       Luke    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 7  Schlachter   Margaret    SUBSCRIBER      ACTIVE   SHARE      HDHP
#
#    Activity Campaigns (VP Team Challenges) **  \
# 0                                         2.0
# 1                                         6.0
# 5                                         2.0
# 6                                         1.0
# 7                                         1.0
#
#    Last Health Assessment (VP Health Check)  \
# 0                                         1
# 1                                         1
# 5                                         0
# 6                                         0
# 7                                         1
#
#    Last Digital Coaching (1 VP Journey)  \
# 0                                     1
# 1                                     1
# 5                                     0
# 6                                     0
# 7                                     1
#
#    Health Screening (Worksite or Provider)
# 0                                        1
# 1                                        1
# 5                                        1
# 6                                        0
# 7                                        1

# %%
# Pulling in data from our gsheets database into a new dataframe. 

gc = gspread.service_account(filename="/Users/travismagaluk/Documents/Coding Work/Other Wasatch Projects/Health_and_Wellness_Emails/excellent-range-359215-54acfee9562d.json")

sh = gc.open("Health And Wellness Tracking")

ws = sh.worksheet('Sheet1')

df = pd.DataFrame(ws.get_all_records())

df.head()
# Out:
#     Last Name First Name                      Email Address  \
# 0    Anderson       Ryan  travis.magaluk@wasatchacademy.org
# 1  Applegarth       Paul  travis.magaluk@wasatchacademy.org
# 2      Bagley       Lori  travis.magaluk@wasatchacademy.org
# 3    Barkdull     Jolean  travis.magaluk@wasatchacademy.org
# 4      Bedell      Kerry  travis.magaluk@wasatchacademy.org
#
#   Initiatives Completed Reimbursements Received Reimbursement Left  \
# 0                     0                       0                100
# 1                     0                       0                100
# 2                     4                       0                100
# 3                     2                       0                100
# 4                     5                      50                 50
#
#   Last Email Sent (Y/N) Current Employee (Y/N)
# 0                     N                      Y
# 1                     N                      N
# 2                     N                      Y
# 3                     N                      Y
# 4                     N                      Y

# %%
# Play around with getting these to merge into one nice dataframe that we can use with the email generation part
# of this program. 

test = pd.merge(result, df, how="inner", on=["First Name", "Last Name"])

# %%
test.head()
# Out:
#     Last Name First Name Member Status Plan Status Product Plan Type  \
# 0     Magaluk     Travis    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 1       Prows   Michelle    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 2    Anderson       Ryan    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 3    Peterson       Luke    SUBSCRIBER      ACTIVE   SHARE      HDHP
# 4  Schlachter   Margaret    SUBSCRIBER      ACTIVE   SHARE      HDHP
#
#    Activity Campaigns (VP Team Challenges) **  \
# 0                                         2.0
# 1                                         6.0
# 2                                         2.0
# 3                                         1.0
# 4                                         1.0
#
#    Last Health Assessment (VP Health Check)  \
# 0                                         1
# 1                                         1
# 2                                         0
# 3                                         0
# 4                                         1
#
#    Last Digital Coaching (1 VP Journey)  \
# 0                                     1
# 1                                     1
# 2                                     0
# 3                                     0
# 4                                     1
#
#    Health Screening (Worksite or Provider)                      Email Address  \
# 0                                        1  travis.magaluk@wasatchacademy.org
# 1                                        1  travis.magaluk@wasatchacademy.org
# 2                                        1  travis.magaluk@wasatchacademy.org
# 3                                        0  travis.magaluk@wasatchacademy.org
# 4                                        1  travis.magaluk@wasatchacademy.org
#
#   Initiatives Completed Reimbursements Received Reimbursement Left  \
# 0
# 1
# 2                     0                       0                100
# 3
# 4
#
#   Last Email Sent (Y/N) Current Employee (Y/N)
# 0
# 1
# 2                     N                      Y
# 3
# 4

# %%
test.shape
# Out:
# (5, 16)

# %%
test.columns

col_names = ['First Name', 'Last Name', 'Email Address',
       'Health Screening (Worksite or Provider)',
       'Last Health Assessment (VP Health Check)',
       'Last Digital Coaching (1 VP Journey)',
       'Activity Campaigns (VP Team Challenges) **',
       'Initiatives Completed', 'Reimbursements Received',
       'Reimbursement Left', 'Last Email Sent (Y/N)',
       'Current Employee (Y/N)']

test = test[col_names]

# %%
def reorder_rename_cols(old_df):
    list_of_column_names = ['First Name',
                            'Last Name',
                            'Email Address',
                            'Health Screening (Worksite or Provider)',
                            'Last Health Assessment (VP Health Check)',
                            'Last Digital Coaching (1 VP Journey)',
                            'Activity Campaigns (VP Team Challenges) **',
                            'Initiatives Completed',
                            'Reimbursements Received',
                            'Reimbursement Left',
                            'Last Email Sent (Y/N)',
                            'Current Employee (Y/N)']

    old_df = old_df[list_of_column_names].copy()
    renamed_df = old_df.rename(columns={'Health Screening (Worksite or Provider)': 'Health Screening',
                                        'Last Health Assessment (VP Health Check)': 'Health Assessment',
                                        'Activity Campaigns (VP Team Challenges) **': 'Activity Campaigns'})
    return renamed_df

# %%
test4 = reorder_rename_cols(test)

# %%
def completed_check(person_data, item, output):

    if person_data[item] == 1:
        completed.append(output)
    else:
        un_completed.append(output)

# %%
def data_gather(person_data):
    
    requirements = ({3: 'Health Screening',
                     4: 'Health Assessment',
                     5: 'Digital Coaching (VP Journey)',
                     6: 'First Activity Campaign',
                     7: 'Second Activity Campaign',
                 })
    
    f_name = person_data[0]
    l_name = person_data[1]
    email = person_data[2]
    completed = []
    un_completed = []
    
    for j in range(3,6):
        completed_check(person_data, j, requirements[j])
    
    return f_name, l_name, email, completed, un_completed

# %%
test4.head()
# Out:
#   First Name   Last Name                      Email Address  Health Screening  \
# 0     Travis     Magaluk  travis.magaluk@wasatchacademy.org                 1
# 1   Michelle       Prows  travis.magaluk@wasatchacademy.org                 1
# 2       Ryan    Anderson  travis.magaluk@wasatchacademy.org                 1
# 3       Luke    Peterson  travis.magaluk@wasatchacademy.org                 0
# 4   Margaret  Schlachter  travis.magaluk@wasatchacademy.org                 1
#
#    Health Assessment  Last Digital Coaching (1 VP Journey)  \
# 0                  1                                     1
# 1                  1                                     1
# 2                  0                                     0
# 3                  0                                     0
# 4                  1                                     1
#
#    Activity Campaigns Initiatives Completed Reimbursements Received  \
# 0                 2.0
# 1                 6.0
# 2                 2.0                     0                       0
# 3                 1.0
# 4                 1.0
#
#   Reimbursement Left Last Email Sent (Y/N) Current Employee (Y/N)
# 0
# 1
# 2                100                     N                      Y
# 3
# 4

# %%
person_data1= test4.iloc[1]

# %%
data_gather(person_data1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 data_gather(person_data1)
#
# Input In [54], in data_gather(person_data)
#      14 un_completed = []
#      16 for j in range(3,6):
# ---> 17     completed_check(person_data, j, requirements[j])
#      19 return f_name, l_name, email, completed, un_completed
#
# Input In [53], in completed_check(person_data, item, output)
#       1 def completed_check(person_data, item, output):
#       3     if person_data[item] == 1:
# ----> 4         completed.append(output)
#       5     else:
#       6         un_completed.append(output)
#
# NameError: name 'completed' is not defined

# %%
person_data1[0]
# Out:
# 'Michelle'

# %%
# for i in range(len(test4)):
#     person_data = test4.iloc[i]
#     print(person_data)
